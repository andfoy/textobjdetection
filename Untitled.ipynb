# %%
# %env NO_CUDA 1

import cv2
import torch
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
% matplotlib inline

from ssd import v2
from ssd.ssd import build_ssd
from lstm_model import RNNModel
from ssd.layers.modules import MultiBoxLoss

# from ssd.data import BaseTransform
from torch.utils.data import DataLoader
from torchvision import transforms, models
from visual_genome_loader import (VisualGenomeLoader,
                                  AnnotationTransform,
                                  ResizeTransform,
                                  detection_collate)
# Out:
# env: NO_CUDA=1

# %%
with open('demo/corpus.pt', 'rb') as f:
    corpus = torch.load(f)
    
net = build_ssd('train', 300, 150)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-ffd58c1e1195> in <module>()
#       2     corpus = torch.load(f)
#       3
# ----> 4 net = build_ssd('train', 300, 150)
#
# /home/andfoy/Documentos/dev-projects/instanceobjseg/ssd/ssd.py in build_ssd(phase, size, num_classes)
#     216     return SSD(phase, *multibox(vgg(base[str(size)], 3),
#     217                                 add_extras(extras[str(size)], 1024),
# --> 218                                 mbox[str(size)], num_classes), num_classes)
#
# /home/andfoy/Documentos/dev-projects/instanceobjseg/ssd/ssd.py in __init__(self, phase, base, extras, head, num_classes)
#      34         # TODO: implement __call__ in PriorBox
#      35         self.priorbox = PriorBox(v2)
# ---> 36         self.priors = Variable(self.priorbox.forward(), volatile=True)
#      37         self.size = 300
#      38
#
# /home/andfoy/Documentos/dev-projects/instanceobjseg/ssd/layers/functions/prior_box.py in forward(self)
#      92         output = torch.Tensor(mean).view(-1, 4)
#      93         if self.clip:
# ---> 94             output.clamp_(max=1, min=0)
#      95         return output
#
# RuntimeError: cuda runtime error (8) : invalid device function at /data/users/soumith/miniconda2/conda-bld/pytorch-0.1.10_1488755368782/work/torch/lib/THC/generated/../generic/THCTensorMathPointwise.cu:101

# %%
img = Image.open('demo/2353025.jpg').convert('RGB')
plt.imshow(img)

# %%
transform = transforms.Compose([
      ResizeTransform((300, 300)),
      transforms.ToTensor(),
      transforms.Normalize(
          mean=[0.485, 0.456, 0.406],
          std=[0.229, 0.224, 0.225])])

# %%
input_img = transform(img)
phrase = 'Man throwing frisbee'
